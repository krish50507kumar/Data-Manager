# %%
from data_manager.storage.json_backend import JSONStorage

# %%
JsonDataManager = JSONStorage()

# %%
test_data_path = "D:\\workspace\\Dev tools\\PythonProjects\\DataManager\\tests\\Data\\test_data_2.json"

# %%
JsonDataManager.load(test_data_path)

# %%
JsonDataManager.dd.head()
# Out:
#    id     name   age   salary department       city  experience  rating  \
# 0   1    Alice  25.0  50000.0         IT      Delhi         2.0     4.5
# 1   2      Bob   NaN  60000.0         HR     Mumbai         4.0     4.2
# 2   3  Charlie  30.0      NaN    Finance  Bangalore         6.0     NaN
# 3   4      NaN  28.0  55000.0         IT        NaN         3.0     4.1
# 4   5      Eva  22.0  45000.0  Marketing       Pune         NaN     3.9
#
#    active                email
# 0    True    alice@example.com
# 1    True      bob@example.com
# 2   False  charlie@example.com
# 3    True    david@example.com
# 4    True                  NaN
